# %%
#For bin/exe to png
import numpy as np
from PIL import Image
from IPython.display import display

# %%
# Define width and height
# Arbitrary at the momment
width, height = 250, 250

# %%
# Read file using numpy "fromfile()"
# Works with a wide range of file types, converts them into binary format with mode 'rb'
with open('SteamSetup.exe', mode='rb') as f:
    imageData = np.fromfile(f,dtype=np.uint8,count=width*height).reshape(height,width)

# %%
# Make into PIL Image and save
PILimage = Image.fromarray(imageData)
PILimage.save('result.png')

# %%
display(Image.open('result.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=250x250 at 0x7F0F6072DE50>

# %%
#On malwarebytes antivirus for ironic purposes only
with open('MBSetup.exe', mode='rb') as f:
    imageData = np.fromfile(f,dtype=np.uint8,count=width*height).reshape(height,width)

# %%
# Make into PIL Image and save
PILimage = Image.fromarray(imageData)
PILimage.save('result2.png')
display(Image.open('result2.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=250x250 at 0x7F0F620E8CA0>

# %%
#On actual peice of malware
with open('15e029c3834435150c76741e714540fcb799662db8cc2c61ba4ef192a781727b', mode='rb') as f:
    imageData = np.fromfile(f,dtype=np.uint8,count=width*height).reshape(height,width)

# %%
# Make into PIL Image and save
PILimage = Image.fromarray(imageData)
PILimage.save('result3.png')
display(Image.open('result3.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=250x250 at 0x7F0F60715700>
